# %%
import cv2
import numpy as np
import matplotlib.pyplot as mp

# %%
image1=cv2.imread("dog.jpg")
image2=cv2.imread("dog1.jpg")
image1=cv2.cvtColor(image1,cv2.COLOR_BGR2RGB)
image2=cv2.cvtColor(image2,cv2.COLOR_BGR2RGB)

# %%
mp.imshow(image1)

# %%
mp.imshow(image1)

# %%
image=np.hstack([image1,image2])

# %% [markdown]
# mp.imshow(image)

# %%
mp.imshow(image)
